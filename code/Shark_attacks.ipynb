# %%
import numpy as np
import pandas as pd
import re
import warnings

# %%
#Importing the CSV into a dataframe
df_sharks = pd.read_csv("../data/Shark_attacks.csv",encoding="unicode_escape")

# %%
#first we look at the shape and print a sample
df_sharks.shape
df_sharks.sample(frac=0.4)
# Out:
#         Case Number                  Date    Year        Type  \
# 19845           NaN                   NaN     NaN         NaN
# 18147           NaN                   NaN     NaN         NaN
# 16938           NaN                   NaN     NaN         NaN
# 7729              0                   NaN     NaN         NaN
# 22490           NaN                   NaN     NaN         NaN
# ...             ...                   ...     ...         ...
# 5978   1861.02.12.R  Reported 12-Feb-1861  1861.0  Unprovoked
# 8100              0                   NaN     NaN         NaN
# 18277           NaN                   NaN     NaN         NaN
# 7760              0                   NaN     NaN         NaN
# 14146           NaN                   NaN     NaN         NaN
#
#                             Country                Area Location  Activity  \
# 19845                           NaN                 NaN      NaN       NaN
# 18147                           NaN                 NaN      NaN       NaN
# 16938                           NaN                 NaN      NaN       NaN
# 7729                            NaN                 NaN      NaN       NaN
# 22490                           NaN                 NaN      NaN       NaN
# ...                             ...                 ...      ...       ...
# 5978   EQUATORIAL GUINEA / CAMEROON  Fernando Po Island      NaN  Swimming
# 8100                            NaN                 NaN      NaN       NaN
# 18277                           NaN                 NaN      NaN       NaN
# 7760                            NaN                 NaN      NaN       NaN
# 14146                           NaN                 NaN      NaN       NaN
#
#                  Name Sex   ... Species            Investigator or Source  \
# 19845             NaN  NaN  ...      NaN                              NaN
# 18147             NaN  NaN  ...      NaN                              NaN
# 16938             NaN  NaN  ...      NaN                              NaN
# 7729              NaN  NaN  ...      NaN                              NaN
# 22490             NaN  NaN  ...      NaN                              NaN
# ...               ...  ...  ...      ...                              ...
# 5978   William Looney    M  ...      NaN  Daily Southern Cross, 2/12/1861
# 8100              NaN  NaN  ...      NaN                              NaN
# 18277             NaN  NaN  ...      NaN                              NaN
# 7760              NaN  NaN  ...      NaN                              NaN
# 14146             NaN  NaN  ...      NaN                              NaN
#
#                            pdf  \
# 19845                      NaN
# 18147                      NaN
# 16938                      NaN
# 7729                       NaN
# 22490                      NaN
# ...                        ...
# 5978   1861.02.12.R-Looney.pdf
# 8100                       NaN
# 18277                      NaN
# 7760                       NaN
# 14146                      NaN
#
#                                             href formula  \
# 19845                                                NaN
# 18147                                                NaN
# 16938                                                NaN
# 7729                                                 NaN
# 22490                                                NaN
# ...                                                  ...
# 5978   http://sharkattackfile.net/spreadsheets/pdf_di...
# 8100                                                 NaN
# 18277                                                NaN
# 7760                                                 NaN
# 14146                                                NaN
#
#                                                     href Case Number.1  \
# 19845                                                NaN           NaN
# 18147                                                NaN           NaN
# 16938                                                NaN           NaN
# 7729                                                 NaN           NaN
# 22490                                                NaN           NaN
# ...                                                  ...           ...
# 5978   http://sharkattackfile.net/spreadsheets/pdf_di...  1861.02.12.R
# 8100                                                 NaN           NaN
# 18277                                                NaN           NaN
# 7760                                                 NaN           NaN
# 14146                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 19845           NaN            NaN         NaN         NaN
# 18147           NaN            NaN         NaN         NaN
# 16938           NaN            NaN         NaN         NaN
# 7729            NaN            NaN         NaN         NaN
# 22490           NaN            NaN         NaN         NaN
# ...             ...            ...         ...         ...
# 5978   1861.02.12.R          325.0         NaN         NaN
# 8100            NaN            NaN         NaN         NaN
# 18277           NaN            NaN         NaN         NaN
# 7760            NaN            NaN         NaN         NaN
# 14146           NaN            NaN         NaN         NaN
#
# [10289 rows x 24 columns]

# %%
# check the empty columns and drop them, the 2 columns mentioned below seemed empty
df_sharks["Unnamed: 22"].isna().value_counts()
df_sharks["Unnamed: 23"].isna().value_counts()
df_sharks = df_sharks.drop(columns=["Unnamed: 22","Unnamed: 23"])

# %%
#check columns with irrelevent information and or not clear information

df_sharks = df_sharks.drop(columns=["href formula","pdf","href","original order"])

# %%
#check for duplicates
df_sharks[df_sharks.duplicated()]
df_sharks.duplicated().sum()
# Out:
# 19418

# %%
#drop duplicates
df_sharks = df_sharks.drop_duplicates()

# %%
df_sharks.shape
# Out:
# (6305, 18)

# %%
#check and drop all the rows where EVERY value in that row is missing
df_sharks = df_sharks.dropna(axis = 0, how = 'all')
df_sharks.shape
# the dataset went from 25723 row to 6304 after deleting the empty ones
# Out:
# (6304, 18)

# %%
#it's important to check column´s name in order to avoid keyerror
print(df_sharks.columns)
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'Case Number.1', 'Case Number.2'],
#       dtype='object')

# %%
#check if the 3 columns named "Case Number" are equal ==> they are not but it's because of mismatching format date
df_sharks["Case Number.1"].equals(df_sharks["Case Number.2"])
df_sharks["Case Number"].equals(df_sharks["Case Number.1"])
df_sharks["Case Number"].equals(df_sharks["Case Number.2"])
# Out:
# False

# %%
#it's not an information that I see useful, so I'll delete the columns, and also because I already have 2 other columns with dates
df_sharks = df_sharks.drop(columns=["Case Number.1","Case Number.2"])

# %%
df_sharks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species           Investigator or Source
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper

# %%
#after deleting the the columns that are not relevant at this point, let's check the columns names again and clean them
print(df_sharks.columns)
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source'],
#       dtype='object')

# %%
#printing the columns' names helps detect the hidden caracters that can't be detected from looking directly at the table.
#It seems that the colums "Sex" and "Species" have spaces at the end. let's clean them

# %%
df_sharks.rename(columns={"Sex ":"Sex"}, inplace=True)
df_sharks.rename(columns={"Species ":"Species"}, inplace=True)

# %%
print(df_sharks.columns)
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species', 'Investigator or Source'],
#       dtype='object')

# %%
df_sharks.shape
# Out:
# (6304, 16)

# %%
#making sure that all rows missing the columns in the code are dropped
df_sharks.dropna(axis=0, inplace=True, how="all", subset=["Age", "Type","Activity","Country","Fatal (Y/N)","Species"])

# %%
#now let's look at the content of each column and see if there are missing or mismatching info
#the 3 columns "Case Number,Date and Year" seem a little bit similar, so to make it more efficient and less redundant, 
#we'll split the Date column into 2 (month,year)
#and then drop the column Case Number, the Year column will be automatically replaced
df_sharks[["Month"]] = df_sharks["Date"].str.lower().str.extract(r'-(\w{3})-')
df_sharks[["Year"]] = df_sharks["Date"].str.extract(r'(\d{4})')

# %%
#now i'll drop the "Case Number" column, since i have a year and a month columns already
df_sharks = df_sharks.drop(columns=["Case Number"])

# %%
df_sharks.shape
df_sharks.head()
# now the dataset went from 8703 row and 24 columns to  (6304, 16) after deleting the empty ones
# Out:
#           Date  Year        Type    Country             Area  \
# 0  25-Jun-2018  2018     Boating        USA       California
# 1  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2  09-Jun-2018  2018     Invalid        USA           Hawaii
# 3  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018  2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex  Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time          Species          Investigator or Source Month
# 0          18h00      White shark                R. Collier, GSAF   jun
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com   jun
# 2          07h45              NaN  K.McMurray, TrackingSharks.com   jun
# 3            NaN        2 m shark                  B. Myatt, GSAF   jun
# 4            NaN  Tiger shark, 3m                       A .Kipper   jun

# %%
#now we start cleaning the content, and check for empty fields
pd.isna(df_sharks).sum()
# Out:
# Date                         0
# Year                        19
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# Month                      910
# dtype: int64

# %%
#At this point, the "Type" column doesnt need much cleaning
df_sharks['Type'].isna().value_counts()
# Out:
# False    6298
# True        4
# Name: Type, dtype: int64

# %%
#check for unique values
df_sharks["Type"].unique()
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', nan, 'Boat', 'Boatomg'], dtype=object)

# %%
#Replacing cells that contain the word "boat" by "boating" to group them, also transforming Invalid into unknown

df_sharks["Type"] = df_sharks["Type"].str.replace("Boating","Boat")
df_sharks["Type"] = df_sharks["Type"].str.replace("Boatomg","Boat")
df_sharks["Type"] = df_sharks["Type"].str.replace("Invalid","Unknown")

df_sharks["Type"].unique()
df_sharks["Type"].value_counts()
# Out:
# Unprovoked      4595
# Provoked         574
# Unknown          547
# Boat             341
# Sea Disaster     239
# Questionable       2
# Name: Type, dtype: int64

# %%
#Creating a new column to summerize the type coloumn into a provoked accident or not, assuming that "boating" 
#and "sea disaster" are nor provoked, this column will contain that values (Yes/No)
provoked_= ["Unprovoked","Boat","Sea Disaster"]
df_sharks["Provoked"] = df_sharks["Type"].str.contains('|'.join(provoked_)).apply(lambda x: "N" if x == True else "Y")

# %%
#Replacing the empty fields in the Country column with "Unknown"
#Tranforming all the strings in this column into uppercase for unicity
df_sharks["Country"].isna().sum()
df_sharks["Country"]= df_sharks["Country"].str.upper()
df_sharks["Country"].fillna("Unknown", inplace=True)

#not much to change in the country column in my opinion, because more than 50% of incidents are happening in 7 countries

# %%
#check country value count
check = df_sharks["Country"].value_counts()

print(check.to_string())
# Out:
# USA                                      2229
# AUSTRALIA                                1338
# SOUTH AFRICA                              579
# PAPUA NEW GUINEA                          134
# NEW ZEALAND                               128
# BRAZIL                                    112
# BAHAMAS                                   109
# MEXICO                                     89
# ITALY                                      71
# FIJI                                       65
# PHILIPPINES                                61
# REUNION                                    60
# NEW CALEDONIA                              53
# Unknown                                    50
# CUBA                                       46
# MOZAMBIQUE                                 45
# SPAIN                                      44
# INDIA                                      40
# EGYPT                                      38
# CROATIA                                    34
# JAPAN                                      34
# PANAMA                                     32
# SOLOMON ISLANDS                            30
# IRAN                                       29
# JAMAICA                                    27
# GREECE                                     25
# FRENCH POLYNESIA                           25
# HONG KONG                                  24
# INDONESIA                                  23
# ENGLAND                                    23
# COSTA RICA                                 17
# ATLANTIC OCEAN                             17
# PACIFIC OCEAN                              17
# BERMUDA                                    16
# VIETNAM                                    15
# TONGA                                      15
# VANUATU                                    14
# SRI LANKA                                  14
# FRANCE                                     13
# MARSHALL ISLANDS                           13
# TURKEY                                     12
# CANADA                                     12
# SOUTH ATLANTIC OCEAN                       12
# IRAQ                                       12
# VENEZUELA                                  11
# UNITED KINGDOM                             11
# SENEGAL                                    11
# KENYA                                      10
# MAURITIUS                                  10
# NEW GUINEA                                 10
# ECUADOR                                     9
# SIERRA LEONE                                9
# COLUMBIA                                    9
# TAIWAN                                      9
# SEYCHELLES                                  8
# SOUTH KOREA                                 8
# SAMOA                                       8
# SCOTLAND                                    8
# THAILAND                                    8
# CARIBBEAN SEA                               8
# CHILE                                       8
# TANZANIA                                    8
# MADAGASCAR                                  8
# CHINA                                       7
# NORTH PACIFIC OCEAN                         7
# DOMINICAN REPUBLIC                          7
# INDIAN OCEAN                                7
# ISRAEL                                      7
# YEMEN                                       7
# SOMALIA                                     6
# BARBADOS                                    6
# SINGAPORE                                   6
# NEW BRITAIN                                 6
# LIBYA                                       6
# KIRIBATI                                    6
# OKINAWA                                     6
# NICARAGUA                                   6
# MID ATLANTIC OCEAN                          5
# SAUDI ARABIA                                5
# MALAYSIA                                    5
# PALAU                                       5
# MALTA                                       5
# TURKS & CAICOS                              5
# AZORES                                      5
# NORTH ATLANTIC OCEAN                        4
# EL SALVADOR                                 4
# BURMA                                       4
# URUGUAY                                     4
# GRENADA                                     4
# PERSIAN GULF                                4
# HONDURAS                                    4
# GUAM                                        4
# SUDAN                                       4
# NIGERIA                                     4
# RUSSIA                                      4
# LEBANON                                     3
# CEYLON                                      3
# GUINEA                                      3
# GUYANA                                      3
# PORTUGAL                                    3
# HAITI                                       3
# MARTINIQUE                                  3
# TUNISIA                                     3
# AMERICAN SAMOA                              3
# MICRONESIA                                  3
# MONTENEGRO                                  3
# CAPE VERDE                                  3
# LIBERIA                                     3
# BELIZE                                      3
# TRINIDAD & TOBAGO                           3
#  TONGA                                      3
# WEST INDIES                                 2
# YEMEN                                       2
# NORWAY                                      2
# UNITED ARAB EMIRATES (UAE)                  2
# EGYPT                                       2
# SOUTH PACIFIC OCEAN                         2
# CRETE                                       2
# CENTRAL PACIFIC                             2
# SOUTHWEST PACIFIC OCEAN                     2
# CAYMAN ISLANDS                              2
# UNITED ARAB EMIRATES                        2
# MEDITERRANEAN SEA                           2
# ANTIGUA                                     2
# JOHNSTON ISLAND                             2
# ST HELENA, BRITISH OVERSEAS TERRITORY       2
# NAMIBIA                                     2
# TOBAGO                                      2
# PACIFIC OCEAN                               2
# ICELAND                                     2
# TUVALU                                      1
# KOREA                                       1
# GREENLAND                                   1
# MONACO                                      1
# ALGERIA                                     1
# COAST OF AFRICA                             1
# PERU                                        1
# SAN DOMINGO                                 1
# GHANA                                       1
# ASIA?                                       1
# IRELAND                                     1
# KUWAIT                                      1
# RED SEA?                                    1
# REUNION ISLAND                              1
# FALKLAND ISLANDS                            1
# ITALY / CROATIA                             1
# COOK ISLANDS                                1
# ROATAN                                      1
# CYPRUS                                      1
# SWEDEN                                      1
# ANDAMAN ISLANDS                             1
# BAHREIN                                     1
# DJIBOUTI                                    1
# PARAGUAY                                    1
# BRITISH NEW GUINEA                          1
# INDIAN OCEAN?                               1
# BETWEEN PORTUGAL & INDIA                    1
# OCEAN                                       1
# GEORGIA                                     1
# AFRICA                                      1
# SYRIA                                       1
# TASMAN SEA                                  1
# EQUATORIAL GUINEA / CAMEROON                1
# COMOROS                                     1
# CURACAO                                     1
# GRAND CAYMAN                                1
# RED SEA                                     1
# BRITISH ISLES                               1
# WESTERN SAMOA                               1
# BANGLADESH                                  1
# SOUTH CHINA SEA                             1
# ANGOLA                                      1
# NORTHERN ARABIAN SEA                        1
# EGYPT / ISRAEL                              1
# MEXICO                                      1
# ST. MAARTIN                                 1
# SLOVENIA                                    1
# GULF OF ADEN                                1
# BRITISH VIRGIN ISLANDS                      1
# NEVIS                                       1
# MALDIVES                                    1
# PALESTINIAN TERRITORIES                     1
# DIEGO GARCIA                                1
# ST. MARTIN                                  1
# PUERTO RICO                                 1
# ARUBA                                       1
# FEDERATED STATES OF MICRONESIA              1
# ADMIRALTY ISLANDS                           1
# BRITISH WEST INDIES                         1
# RED SEA / INDIAN OCEAN                      1
# MID-PACIFC OCEAN                            1
# BAY OF BENGAL                               1
# SOLOMON ISLANDS / VANUATU                   1
#  PHILIPPINES                                1
# JAVA                                        1
# IRAN / IRAQ                                 1
# NORTHERN MARIANA ISLANDS                    1
# NETHERLANDS ANTILLES                        1
# GUATEMALA                                   1
# ARGENTINA                                   1
# SUDAN?                                      1
# THE BALKANS                                 1
# NORTH ATLANTIC OCEAN                        1
# MAYOTTE                                     1
# GABON                                       1
# ANDAMAN / NICOBAR ISLANDAS                  1
# MALDIVE ISLANDS                             1
# NICARAGUA                                   1
# NORTH SEA                                   1
# CEYLON (SRI LANKA)                          1

# %%
df_sharks.shape
# Out:
# (6302, 17)

# %%
df_sharks["Country"].isna().sum()
# Out:
# 0

# %%
#checking the column "Area"
#Replacing the empty fields in the "Area" column with "Unknown"

df_sharks["Area"].isna().sum()
df_sharks["Area"].fillna("Unknown", inplace=True)

# %%
df_sharks["Area"].isna().sum()
# Out:
# 0

# %%
#checking the column "Location"
#Replacing the empty fields in the "Location" column with "Unknown"
df_sharks["Location"].isna().sum()
df_sharks["Location"].fillna("Unknown", inplace=True)

# %%
#not much change in the columns "Area,Location,Country", except from filling all the blanks with "unknown"

# %%
#checking again the number of columns and dropping some, since I created new ones
df_sharks.head()
# Out:
#           Date  Year        Type    Country             Area  \
# 0  25-Jun-2018  2018        Boat        USA       California
# 1  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2  09-Jun-2018  2018     Unknown        USA           Hawaii
# 3  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018  2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex  Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M    0
# 4                        La Ticla  Free diving   Gustavo Ramos    M    0
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time          Species          Investigator or Source Month  \
# 0          18h00      White shark                R. Collier, GSAF   jun
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com   jun
# 2          07h45              NaN  K.McMurray, TrackingSharks.com   jun
# 3            NaN        2 m shark                  B. Myatt, GSAF   jun
# 4            NaN  Tiger shark, 3m                       A .Kipper   jun
#
#   Provoked
# 0        N
# 1        N
# 2        Y
# 3        N
# 4        Y

# %%
#checking the column "Activity"
df_sharks["Activity"].value_counts()
df_sharks["Activity"].isna().sum()

#we have some cell that contains the words surf==> to be grouped with Surfing, same for cells that contain 
#swim, bathing...==> Swimming
# Out:
# 0

# %%
for row in df_sharks["Activity"]:
    #Replacing all swimming related strings with "Swimming"
    if re.search(".*wimm.*", str(row)) or re.search(".*swim.*", str(row)):
        df_sharks["Activity"] = df_sharks["Activity"].str.replace(row, "Swimming")
    if row=="Bathing" or row=="Floating":
        df_sharks["Activity"] = df_sharks["Activity"].str.replace(row, "Swimming")
    if re.search(".*(T|t)reading.*", str(row)):
        df_sharks["Activity"] = df_sharks["Activity"].str.replace(row, "Swimming")
    #==> Replace surfing related strings with "Surfing"
    if re.search(".*surf.*", str(row)): 
        df_sharks["Activity"] = df_sharks["Activity"].str.replace(row, "Surfing")
# Out:
# C:\Users\34603\AppData\Local\Temp\ipykernel_12408\3165733822.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_sharks["Activity"] = df_sharks["Activity"].str.replace(row, "Surfing")
# C:\Users\34603\AppData\Local\Temp\ipykernel_12408\3165733822.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_sharks["Activity"] = df_sharks["Activity"].str.replace(row, "Swimming")
# C:\Users\34603\AppData\Local\Temp\ipykernel_12408\3165733822.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_sharks["Activity"] = df_sharks["Activity"].str.replace(row, "Swimming")

# %%
df_sharks["Activity"].value_counts()
df_sharks["Activity"].isna().sum()
# Out:
# 0

# %%
#replacing the nans values with "Unknown"
df_sharks["Activity"].fillna("Unknown", inplace=True)

# %%
#checking the column "Name"
#Replacing the empty fields in the "Name" column with "Unknown"
df_sharks["Name"].isna().sum()
df_sharks["Name"].fillna("Unknown", inplace=True)

# %%
#unify the column "Sex"
df_sharks["Sex"].unique()
# Out:
# array(['F', 'M', 'Unknown'], dtype=object)

# %%
#transforming values like "N" or "M " ==> "M"
#the rest of the column are replaced by the value "Unknown"

df_sharks["Sex"] = df_sharks["Sex"].str.replace("N", "M")
df_sharks["Sex"] = df_sharks["Sex"].str.replace("M ", "M")
df_sharks["Sex"] = df_sharks["Sex"].str.replace("lli", "Unknown")
df_sharks["Sex"] = df_sharks["Sex"].str.replace(".", "Unknown")
df_sharks["Sex"] = df_sharks["Sex"].str.replace("nan", "Unknown")
df_sharks['Sex'] = df_sharks['Sex'].fillna('Unknown')
df_sharks["Sex"].unique()
# Out:
# C:\Users\34603\AppData\Local\Temp\ipykernel_12408\2187551033.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_sharks["Sex"] = df_sharks["Sex"].str.replace(".", "Unknown")
# array(['F', 'M', 'Unknown'], dtype=object)

# %%
df_sharks.sample(frac=0.5)
# Out:
#                       Date  Year        Type      Country  \
# 1873           25-Mar-2002  2002  Unprovoked          USA
# 5449           11-Sep-1907  1907  Unprovoked      CROATIA
# 1523           25-Nov-2005  2005  Unprovoked    AUSTRALIA
# 5626                  1896  1896  Unprovoked        HAITI
# 410            19-Jun-2015  2015  Unprovoked  PUERTO RICO
# ...                    ...   ...         ...          ...
# 208            10-Oct-2016  2016  Unprovoked          USA
# 2243           17-Jul-1997  1997  Unprovoked       BRAZIL
# 5135  Reported 08-Jan-1927  1927  Unprovoked          USA
# 4290           25-Jul-1955  1955  Unprovoked        JAPAN
# 2697           20-Jan-1989  1989  Unprovoked          USA
#
#                         Area                                        Location  \
# 1873                  Hawaii                  Brenecke Beach, Po'ipu, Kaua'i
# 5449   Split-Dalmatia Count,                           Sucurja, Hvar Island,
# 1523                Victoria                                        Flinders
# 5626        Off Cape Haitien                                         Unknown
# 410                  Unknown                                   Off Cabo Rojo
# ...                      ...                                             ...
# 208                   Oregon  Indian Beach, Ecola State Park, Clatsop County
# 2243              Pernambuco                              Boa Viagem, Recife
# 5135              California            Catalina Channel, Los Angeles County
# 4290      Okayama Prefecture                                 Usimado-no-Seto
# 2697                  Hawaii                         Waialua Beach, Moloka'i
#
#            Activity                                 Name Sex  Age  \
# 1873  Body-boarding                             Hoku Aki   M   17
# 5449       Swimming                               female   F    0
# 1523        Surfing                            Tom Burke   M   18
# 5626         Wading                               Syrian   M   15
# 410    Spearfishing                        Benjamin Rios   M   36
# ...             ...                                  ...  ..  ...
# 208         Surfing                        Joseph Tanner   M   29
# 2243        Surfing  José Roberto Paraizo de Albuquerque   M    0
# 5135       Swimming                         Price Taylor   M    0
# 4290        Unknown                         Hideo Ishida   M   22
# 2697  Body boarding                          Earl Dunnam   M   10
#
#                                         Injury Fatal (Y/N)     Time  \
# 1873               Left leg severed below knee           N    12h00
# 5449                                     FATAL           Y      NaN
# 1523  2 lacerations on leg, each 4" to 5" long           N    18h00
# 5626                    Leg severed below knee           N      NaN
# 410                             Injury to hand           N  Morning
# ...                                        ...         ...      ...
# 208        Wounds to upper thigh and lower leg           N    16h00
# 2243                                  Survived           N      NaN
# 5135                                 Lost hand           N      NaN
# 4290                                     FATAL           Y    13h00
# 2697                               Foot bitten           N      NaN
#
#                                          Species  \
# 1873                                 Tiger shark
# 5449                                         NaN
# 1523                                 1.8 m shark
# 5626                                         NaN
# 410                                          NaN
# ...                                          ...
# 208                                          NaN
# 2243                                         NaN
# 5135                                         NaN
# 4290                                  Blue shark
# 2697  1.8 m to 2.4 m [6' to 8'] hammerhead shark
#
#                                  Investigator or Source Month Provoked
# 1873                  G. Kubota, Honolulu Star Bulletin   mar        N
# 5449                                     C. Moore, GSAF   sep        N
# 1523                  Sydney Morning Herald, 11/25/2005   nov        N
# 5626  C. R. Baker & C.M. Rose;  V.M. Coppleson (1958...   NaN        N
# 410                               Yahoo News, 6/19/2015   jun        N
# ...                                                 ...   ...      ...
# 208                               UP Beacon, 10/12/2016   oct        N
# 2243                                           JCOnline   jul        N
# 5135                        The Afro-American, 1/8/1927   jan        N
# 4290                                          M. Hosina   jul        N
# 2697                                      J. Borg, p.77   jan        N
#
# [3151 rows x 17 columns]

# %%
#cheking the column "Age"
df_sharks["Age"].isna().sum()
df_sharks["Age"].unique()
# Out:
# array([        57,         11,         48,          0,         18,
#                52,         15,         12,         32,         10,
#                21,         34,         30,         60,         33,
#                29,         54,         41,         37,         56,
#                19,         25,         69,         38,         55,
#                35,         46,         45,         14,         40,
#                28,         20,         24,         26,         49,
#                22,          7,         31,         17,         13,
#                42,          3,          8,         50,         16,
#                82,         73,         68,         51,         39,
#                58,         47,         61,         65,         36,
#                66,         43,          9,         72,         59,
#                 6,         27,         64,         23,         71,
#                44,         62,         63,         70,         53,
#                77,         74,       2826,          5,         86,
#              1820,       1213,       4634,     282330,       3626,
#               810,         84,       3036,         75,       3337,
#              2320,        731,       3230,       1618,         87,
#                67,       2126,       1822,        912,       2535,
#              2326,          1,       2528, 3767352727,   21342435,
#              3032,       5030,       1735,       1318,       3419,
#              3326,         81,         78,       1716,        910,
#              3623,       1012,       3133,          2,       1314],
#       dtype=int64)

# %%
#the culumn age is not an integer, we would need to transform it
print(df_sharks.dtypes)
# Out:
# Date                      object
# Year                      object
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                        int64
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# Month                     object
# Provoked                  object
# dtype: object

# %%
#replacing the values using regex to detect digits and drop the rest (aplhabetical or specia characters)
df_sharks["Age"] = df_sharks["Age"].str.replace(r'[^\d.]+', '')
#making sure to remove . as well
df_sharks["Age"] = df_sharks["Age"].str.replace('.', '')
#replacing "nan" value with a zero
df_sharks["Age"] = df_sharks["Age"].replace(np.nan, 0)
#replacing empty cells with a zero (empty strings)
df_sharks["Age"] = df_sharks["Age"].replace('', "0")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [71], in <cell line: 2>()
#       1 #replacing the values using regex to detect digits and drop the rest (aplhabetical or specia characters)
# ----> 2 df_sharks["Age"] = df_sharks["Age"].str.replace(r'[^\d.]+', '')
#       3 #making sure to remove . as well
#       4 df_sharks["Age"] = df_sharks["Age"].str.replace('.', '')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py:177, in StringMethods.__init__(self, data)
#     174 def __init__(self, data):
#     175     from pandas.core.arrays.string_ import StringDtype
# --> 177     self._inferred_dtype = self._validate(data)
#     178     self._is_categorical = is_categorical_dtype(data.dtype)
#     179     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py:231, in StringMethods._validate(data)
#     228 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     230 if inferred_dtype not in allowed_types:
# --> 231     raise AttributeError("Can only use .str accessor with string values!")
#     232 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
#like mentioned before, the column age is not an integer, transform into int64 (int64 to avoid overflow errors)
df_sharks["Age"] = df_sharks["Age"].astype("int64")

# %%
#now we have cells that contain more than 2 digits, which doesn't make sense for Age values
#any value above 99 is going to be replaced by a zero
df_sharks["Age"] = df_sharks["Age"].apply(lambda x: x if x < 99 else 0)

# %%
#now we can calculate the mean age for all values above 0
meanAge = df_sharks[df_sharks["Age"] > 0].mean()
meanAge = int(meanAge)
# Out:
# C:\Users\34603\AppData\Local\Temp\ipykernel_12408\4022355038.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   meanAge = df_sharks[df_sharks["Age"] > 0].mean()

# %%
# Out:
# array([57, 11, 48,  0, 18, 52, 15, 12, 32, 10, 21, 34, 30, 60, 33, 29, 54,
#        41, 37, 56, 19, 25, 69, 38, 55, 35, 46, 45, 14, 40, 28, 20, 24, 26,
#        49, 22,  7, 31, 17, 13, 42,  3,  8, 50, 16, 82, 73, 68, 51, 39, 58,
#        47, 61, 65, 36, 66, 43,  9, 72, 59,  6, 27, 64, 23, 71, 44, 62, 63,
#        70, 53, 77, 74,  5, 86, 84, 75, 87, 67,  1, 81, 78,  2],
#       dtype=int64)

# %%
#replacing all the columns with zero as value with the Mean Age
df_sharks["Age"] = df_sharks['Age'].apply(lambda x: x if x > 0 else meanAge)

# %%
#the mean value did not change
df_sharks["Age"].mean()
df_sharks["Age"].unique()
# Out:
# array([57, 11, 48, 27, 18, 52, 15, 12, 32, 10, 21, 34, 30, 60, 33, 29, 54,
#        41, 37, 56, 19, 25, 69, 38, 55, 35, 46, 45, 14, 40, 28, 20, 24, 26,
#        49, 22,  7, 31, 17, 13, 42,  3,  8, 50, 16, 82, 73, 68, 51, 39, 58,
#        47, 61, 65, 36, 66, 43,  9, 72, 59,  6, 64, 23, 71, 44, 62, 63, 70,
#        53, 77, 74,  5, 86, 84, 75, 87, 67,  1, 81, 78,  2], dtype=int64)

# %%
#now to the "Fatal (Y/N)" unify the elements in the cells and filling the nans with unknown

# %%
df_sharks["Fatal (Y/N)"].unique()
# Out:
# array(['N', 'Y', nan, 'M', 'UNKNOWN', '2017', ' N', 'N ', 'y'],
#       dtype=object)

# %%
#replacing all the values in the Fatal column in order to get cells only with values==> Y / N / Unknown

df_sharks["Fatal (Y/N)"] = df_sharks["Fatal (Y/N)"].str.replace(" N", "N")
df_sharks["Fatal (Y/N)"] = df_sharks["Fatal (Y/N)"].str.replace("N ", "N")
df_sharks["Fatal (Y/N)"] = df_sharks["Fatal (Y/N)"].str.replace("y", "Y")
df_sharks["Fatal (Y/N)"] = df_sharks["Fatal (Y/N)"].str.replace("2017", "UNKNOWN")
df_sharks["Fatal (Y/N)"] = df_sharks["Fatal (Y/N)"].str.replace("Unknown", "UNKNOWN")
df_sharks["Fatal (Y/N)"] = df_sharks["Fatal (Y/N)"].str.replace("M", "UNKNOWN")

df_sharks["Fatal (Y/N)"] = df_sharks["Fatal (Y/N)"].fillna("UNKNOWN")

# %%
df_sharks["Fatal (Y/N)"].value_counts()
# Out:
# N          4301
# Y          1389
# UNKNOWN     612
# Name: Fatal (Y/N), dtype: int64

# %%
df_sharks.sample()
# Out:
#              Date  Year      Type       Country                   Area  \
# 4093  30-May-1959  1959  Provoked  SOUTH AFRICA  Eastern Cape Province
#
#                     Location      Activity        Name Sex  Age  \
# 4093  Bird Island, Algoa Bay  Spearfishing  Tony Dicks   M   23
#
#                                                  Injury Fatal (Y/N) Time  \
# 4093  No injury, diver shot shark & it bit his spear...           N  NaN
#
#                                Species         Investigator or Source Month  \
# 4093  White shark, 2.7 m [9'], 280-lb   C. Middleton; M. Levine, GSAF   may
#
#      Provoked
# 4093        Y

# %%
print(df_sharks.columns)
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species',
#        'Investigator or Source', 'Month', 'Provoked'],
#       dtype='object')

# %%
#it seems like some accident weren't related to sharks, so i created a array of values and droped them from the table since
#our main focus is the Shark attacks

# %%
no_shark = ["Death may have been due to drowning","Doubtful / Unconfirmed attack / Unable to verify in local records","No shark invovlement","No shark involvement","No shark invovlement - it ws a publicity stunt",
"Not a shark attack; it was a hoax,Not authenticated","Shark involvement  not confirmed","Shark involvement unconfirmed","Shark involvement suspected but not confirmed","Shark involvement questionable","Shark involvement prior to deaths was not confirmed",
"Shark involvement prior to death was not confirmed","Shark involvement prior to deaths unconfirmed","Shark involvement prior to death unconfired","Shark involvement prior to death unconfirmed","Shark involvement prior to death still to be determined","Shark involvement prior to death suspected but not confirmed"
"Shark involvement prior to death remains unconfirmed","Shark involvement prior to death not confirmed","Shark involvement prior to death remains unconfirmed","Shark involvement prior to death not confirmed",
"Shark involvement not confirmed","thought to be a barracuda bite","Shark involvement not confirmed","injury may be due to a stingray","Shark involvement not confirmed","officials considered barracua","Shark involvement not confirmed",
"Shark involvement not confirmed & highly unlikely","Shark involvement highly doubtful,Shark involvement not cofirmed","No shark involvement","Shark involvement not confirmed"]

# %%
#dropping the rows not related to shark attacks
df_sharks = df_sharks[df_sharks['Species'].str.contains('|'.join(no_shark)) == False]

# %%
list(df_sharks["Species"])
# Out:
# ['White shark',
#  '2 m shark',
#  'Tiger shark, 3m',
#  'Tiger shark',
#  "Lemon shark, 3'",
#  "Bull shark, 6'",
#  'Grey reef shark',
#  'Invalid incident',
#  'Tawny nurse shark, 2m',
#  'Tiger shark',
#  'Questionable',
#  '3 m shark',
#  'White shark, 3.5 m',
#  'Tiger shark',
#  'White shark, 2.5 m',
#  "6' shark",
#  'Juvenile bull shark',
#  'Tiger shark',
#  '2 m shark',
#  'Bull shark',
#  'White shark',
#  "Tiger shark, 12'",
#  'Wobbegong shark',
#  '3.5 m shark',
#  '1.8 m shark',
#  'Blacktip shark',
#  'Juvenile white shark,  2.7 to 3.2 m',
#  'Bull shark, 2 m',
#  'Possibly a wobbegong',
#  'Injury believed caused by an eel, not a shark',
#  'Galapagos shark?',
#  '2m shark',
#  'Bull shark',
#  'Bull shark, 3 m ',
#  'Grey reef shark. 2 m',
#  'White shark, 3.5 m',
#  'small shark',
#  'Wobbegong shark?',
#  'Tiger shark',
#  'Juvenile nurse shark',
#  "Nurse shark. 5'",
#  'Tiger shark, female',
#  'Tiger shark, female',
#  'Some drowned but other may have been killed by blue sharks',
#  'White shark, 4.6 m',
#  '2 m shark',
#  'Tiger shark',
#  'Cookiecutter shark',
#  'Wobbegong shark, 1 m',
#  'White shark, 4.5 m',
#  '2 m shark',
#  'Spinner shark, 4 to 5 feet',
#  'Tiger shark, 8 to 10 feet',
#  "8' shark",
#  "5' shark",
#  'White shark, 3.5 m',
#  'Questionable',
#  "4' to 5' shark",
#  'Porbeagle, 1.5 m',
#  'White shark, 3.5m',
#  "5' to 6' shark",
#  'White shark, 3 to 3.5m ',
#  'Nurse shark',
#  'White shark, 3 m',
#  "White shark, 5' to 7'",
#  "5' shark",
#  'Possibly a juvenile blacktip shark',
#  'Oceanic whitetip shark, 1.8 to 2 m',
#  "4' shark",
#  "White shark, 10'",
#  'A small shark',
#  "Sandtiger shark  2'",
#  "Blue shark 6'",
#  '"A small shark"',
#  "White shark, 11' to 13'",
#  "White shark, 8' to 10'",
#  "White shark, 9'",
#  'White shark',
#  "Bull shark, 4' to 5'",
#  'Tiger shark, 100 kg',
#  'White shark, 2.5 m',
#  "Bull shark, 4' to 5'",
#  'Bull shark, 2m',
#  'White shark, 4 m',
#  'Seven-gill shark',
#  '3m shark, probably a smooth hound',
#  "8' shark",
#  'Tiger shark',
#  "3' shark",
#  'Tiger shark',
#  "9' shark",
#  'Shark involvement highly doubtful',
#  'White shark',
#  "Tiger shark, 12'",
#  "Bull shark, 5' to 7'",
#  'White shark',
#  "10' shark",
#  'Lemon shark',
#  'Bull shark, 1.5',
#  'Lemon shark pup',
#  'Tiger shark',
#  "White shark, female, 14'",
#  'Caribbean reef shark',
#  'Bull shark, 4 m',
#  'Bull shark, 1 m',
#  'Bull shark',
#  'a small shark',
#  'White shark, 4 m',
#  'Wobbegong shark, 2m',
#  'White shark',
#  'Broadnose sevengill shark, 1.5 m',
#  'Tiger shark',
#  " 6' to 8' shark",
#  'White shark',
#  'White shark, 3.5 m',
#  '2 m shark',
#  "3' to 4' shark",
#  "Tiger shark, 10'",
#  "White shark, 8' to 10'",
#  'Invalid',
#  "Bull shark, 6'",
#  'Bull shark, 3.5 m',
#  "Tiger shark, 10' ",
#  'Blacktip shark',
#  'Blue shark',
#  'White shark',
#  "Nurse shark, 4'",
#  "Bull shark, 6'",
#  'reef shark, 1m',
#  "Tiger shark, 10' ",
#  "White shark, 10' to 12'",
#  "Lemon shark, 9'",
#  'Angel shark',
#  'White shark',
#  'dogfish shark',
#  'White shark',
#  'Tawny nurse shark',
#  "3' to 4' shark",
#  "Caribbean reef shark, 4.5'",
#  'White shark',
#  "3' to 5' shark",
#  "3' to 4' shark",
#  "5' shark",
#  "3' to 4' shark",
#  "3' shark",
#  "Said to involve an 8' shark but more likely damage caused by debris",
#  '3+ m shark',
#  'Mako shark',
#  'Bronze whaler sharks x 3',
#  '3 m shark',
#  'White shark',
#  "5' shark",
#  "Bull shark, 4' to 5'",
#  "Blacktip shark, 4'",
#  "Nurse shark, 2'",
#  "Mako shark, 1.5 m [5'] ",
#  "Bull shark, 6'",
#  'White shark',
#  'Wobbegong shark',
#  'Grey reef shark, 2 m',
#  'Grey reef shark, 2 m',
#  "Bull shark, 7'",
#  'Tiger shark, 2.5 m',
#  "5' to 6' shark",
#  'Nurse shark, 2.5-ft',
#  'Bronze whaler',
#  'Sandtiger shark',
#  'Sandtiger shark',
#  "Reef shark, 5'",
#  'Bull sharks x 2',
#  'Mako shark',
#  "Tiger shark, 14'",
#  'Wobbegong shark',
#  'Blacktip shark',
#  '3 m shark',
#  'White shark, 3 m',
#  "Silky shark, 6.5'",
#  "9' shark",
#  "Bronze whaler shark, 6'",
#  'Tiger shark, 1.5 m ',
#  'White shark, 3.5 m',
#  'Bull shark',
#  'Galapagos shark',
#  "Spinner shark, 7'",
#  'Bull shark, 2.8 to 3.1 m',
#  "3' to 5' shark",
#  'White shark, 3 to 3.5m ',
#  "5' shark",
#  "Spinner shark, 5'",
#  "Tiger shark, 7'",
#  'Hammerhead sp.',
#  "Tiger shark, 13' ",
#  "4' to 5' shark",
#  "Blacktip shark, 4' to 5'",
#  "Blacktip shark, 5' to 6'",
#  "White shark, 19'",
#  'juvenile shark',
#  "Tiger shark, 13'",
#  "4' shark",
#  'Hammerhead shark',
#  "6' shark",
#  "White shark, 11' to 12'",
#  'Hammerhead shark.',
#  'White shark, 2.5 m',
#  "4' shark?",
#  'small shark',
#  'Tiger shark',
#  "White shark, 11' to 12'",
#  "White shark, 10' to 12' ",
#  "4' shark",
#  "3' shark",
#  "White shark, 13'",
#  "Hammerhead shark. 6' to 7'",
#  'White shark',
#  "Blacktip or spinner shark, 4'",
#  "Thought to involve a 3' to 4' shark, but shark involvement not confirmed",
#  'White shark, 3.9 to 4.2 m',
#  'Mako shark, 100-lb',
#  'Bronze whaler shark, 1.5m',
#  'Bull shark, 2m',
#  'White shark',
#  "White shark, 7'",
#  'Shark involvement not cofirmed',
#  "6' shark",
#  'White shark',
#  'White shark',
#  "6' to 7' shark",
#  "4' to 5' shark",
#  'Bull shark',
#  'White shark',
#  'White shark, 2m to 3 m',
#  "4' shark",
#  'Wobbegong shark',
#  'Sandtiger shark',
#  'White shark',
#  'small shark',
#  'Bull shark',
#  'Bull shark',
#  'Mako shark',
#  "4' shark",
#  "Bull shark, 5'",
#  'small nurse shark',
#  'Bull shark, 2.5 m',
#  '1m to 1.2 m shark',
#  "5' shark",
#  "6' shark",
#  'Bull shark, 3.5 m',
#  'White shark',
#  'White shark, 3.5 m',
#  '3- to 4-foot shark',
#  'White shark, 6 m',
#  'White shark, 3 m',
#  'Blue shark, 8 to 9 feet',
#  'Bull shark',
#  'Bull shark',
#  'Shark involvement not cofirmed',
#  'White shark, 4 m',
#  'Mako shark',
#  'Tiger shark, 8 to 12 feet',
#  'Blacktip shark',
#  'Blacktip Reef shark ',
#  'White shark',
#  'Tiger shark, 3.5 m',
#  '3.5 to 4 m shark',
#  '2 m to  3 m shark',
#  '1.8 m shark',
#  'Bull shark, 1.3 m',
#  "4' shark",
#  'White shark',
#  '5 m shark',
#  '1.5 m shark',
#  'White shark or oceanic whitetip shark',
#  'Raggedtooth shark, 1.3 m',
#  '"A small shark"',
#  '2 m shark',
#  'White shark, 4 to 5 m',
#  "White shark, 8' to 10'",
#  '1.5 m shark',
#  'Goblin shark',
#  'Tiger shark',
#  'White shark',
#  'White shark',
#  "2' shark",
#  '1.5 m shark',
#  "Tiger shark, 12'",
#  'Tiger shark',
#  "12' to 14' shark",
#  '1 m shark',
#  "Bull shark, 3' to 4'",
#  'Blacktip shark',
#  'Blacktip shark',
#  "White shark, 18' to 20'",
#  'White shark',
#  "8' to 10' shark",
#  '2 white shark: 13\' & 9"8"',
#  'Blacktip shark',
#  "7' shark",
#  'Bull shark',
#  "White shark, 12' to 14'",
#  "3' to 4' shark",
#  'Spinner shark',
#  'Spinner shark or blacktip shark',
#  'small shark',
#  "4' to 6' shark",
#  "Bull shark, 4.5' ",
#  "4' shark",
#  'reef shark',
#  " Bull shark, 8'",
#  "Bull shark, 9' to 10'",
#  " Bull shark, 5'",
#  "4' tp 5' shark",
#  'White shark',
#  'Possibly juvenile tiger shark',
#  '1.8 metre shark',
#  'Angel shark',
#  "6' to 8' shark",
#  "4' shark",
#  " White shark, 7' ",
#  "4' to 5' shark",
#  "Oceanic whitetip shark'",
#  "Caribbean reef shark, 7' to 8'",
#  ' Lemon shark, 3.5 m',
#  " Sandbar shark, 3' to 4'",
#  'Bronze whaler shark, 1.5m',
#  'Bull shark',
#  'Blacktip Reef shark ',
#  ' Bull shark, 1.2m ',
#  '3m shark',
#  ' Tawney nurse shark, 1m',
#  " white shark, 15' ",
#  "4' to 5' shark",
#  'Cow shark',
#  "3' shark",
#  'reef shark?',
#  'White shark',
#  ' Raggedtooth shark, 2m',
#  '3 m to 4 m white shark',
#  '2 m shark',
#  "4' to 5' shark",
#  'Wobbegong shark',
#  'Invalid',
#  'Blacktip or spinner shark?',
#  'Blacktip reef shark ',
#  '7-gill shark?',
#  '1m shark',
#  '7-gill shark',
#  'Oceanic whitetip shark',
#  'White shark, 6 m',
#  'Reported to involve a bull shark',
#  'White shark, 3m ',
#  "Tiger shark, 10' to 12'",
#  "4' to 6' shark",
#  ' Wobbegong shark, 1.6 to 1.8m ',
#  'Tiger shark, 3m ',
#  'Thought to involve a white shark',
#  "White shark, 10 '",
#  'Reported to involve a white shark',
#  'Tiger shark',
#  'Blacktip reef shark, 1m',
#  'Thought to involve a bull shark',
#  'Reported to involve a 4 m white shark',
#  'Wobbegong shark',
#  "Whitetip reef shark, 4' to 6'",
#  'Tiger shark',
#  'Nurse shark?',
#  'White shark',
#  'White shark',
#  "White shark, 8' to 10'",
#  'Small bull shark',
#  'Bull shark',
#  "3' shark",
#  "3' shark",
#  "3' shark",
#  'Nurse shark',
#  "4' shark",
#  'Blacktip shark',
#  'Salmon shark',
#  "Mako shark, 5'",
#  'White shark',
#  'Tiger shark?',
#  "Bull shark, 8'",
#  'Blacktip shark',
#  "Bull shark, 6' to 8'",
#  "6' shark",
#  "Tiger shark, 8' to 10' ",
#  'Nurse shark',
#  'White shark',
#  "Possibly a Bull shark, 3'",
#  "4' to 5' shark",
#  "Tiger shark, 14'",
#  "4' to 5' shark",
#  "Lemon shark, 4'",
#  "6' shark",
#  'Galapagos shark',
#  'Galapagos shark',
#  'Invalid',
#  'Bull shark',
#  'a small shark',
#  'Wobbegong, 2m',
#  'Tiger shark',
#  'Grey nurse shark, 3m',
#  "3' shark",
#  'Blue shark',
#  'Bull shark',
#  'Possibly a blacktip reef shark',
#  'shark involvement not confirmed',
#  "4' shark",
#  'Nurse shark',
#  'Raggedtooth shark, 1.5 m',
#  'Tiger shark, 4.8 m',
#  'Bronze whaler shark, 2.5m',
#  '"small sharks"',
#  'White shark, 4m',
#  'reef shark?',
#  'reef shark?',
#  "Blacktip shark, 4' to 5'",
#  'Lemon shark',
#  'White shark, 5m',
#  "Tiger shark, 15'",
#  'Bronze whaler shark, 3m',
#  '2.5 m shark',
#  'Bull shark, 2m ',
#  'Tiger shark',
#  "Tiger shark, 6'",
#  "10' shark",
#  'Sandtiger shark',
#  'Seven-gill shark',
#  "Tiger shark, 10'",
#  '2.5 m shark',
#  "2' to 3' shark",
#  "Tiger shark, 15'",
#  "Tiger shark, 8'",
#  'White shark',
#  "Tiger shark, 10' to 12' ",
#  "White shark, 15' to 16' ",
#  "6' to 8' shark",
#  '2m shark',
#  "5' shark",
#  "4' shark",
#  'Possibly a 3 m bull shark',
#  "3.5' to 4' shark",
#  "Tiger shark, 10' to 12' ",
#  "3.5' to 4' shark",
#  "Porbeagle shark, 7'",
#  '4.5 m shark',
#  "Lemon shark, 4' to 5' ",
#  'Bull shark',
#  'Lemon shark, 2.5m to 3m ',
#  'White shark or bronze whaler',
#  'Thought to involve a white shark',
#  'Salmon shark suspected, but unlikely',
#  'White shark, 5m',
#  "14' to 18'shark",
#  "15' shark",
#  'possibly a bull shark',
#  'a small reef shark',
#  '3 m shark',
#  'Nurse shark',
#  'small blacktip shark?',
#  'small blacktip shark?',
#  'Blacktip shark ',
#  '1.5 m shark',
#  'Blue shark, 2.5m',
#  'White shark, 2 m',
#  '18" to 24" shark',
#  'Bull shark, 3m',
#  "4' to 5' shark",
#  "Tiger shark, 8' to 9' ",
#  'White shark',
#  'White shark',
#  "5' shark",
#  'White shark, 4 m to 5m ',
#  'White shark, 6m ',
#  "Tiger shark, 10'  ",
#  'a small shark',
#  'White shark, 4m ',
#  'White shark',
#  'Possibly a bull shark',
#  "Possibly a 5' to 6' bull shark",
#  "4' to 5' shark",
#  "4' to 5' shark",
#  'Tawny nurse shark, 40cm',
#  "4' shark",
#  'Spinner shark',
#  'Grey nurse shark',
#  'White shark, 7m',
#  "6' to 8' shark",
#  'Tiger shark, 3m',
#  'Tiger shark',
#  'Blue shark, 70-kg blue shark',
#  'White shark, 2.7 m',
#  'Thought to involve a bull shark',
#  'White shark',
#  '2 m shark',
#  'Allegedly a 4 m tiger shark',
#  "7' to 8' shark ",
#  'White shark, 2.5m',
#  'Wobbegong shark',
#  'Wobbegong shark?',
#  "White shark, 15' to 16'",
#  'White shark',
#  "8' to 10' shark",
#  'Raggedtooth shark',
#  "White shark, 10'",
#  "White shark, 15'",
#  'Port Jackson shark, 1m',
#  "3' shark",
#  "10' to 12' shark",
#  '2 to 2.5 m shark',
#  'White shark',
#  "Bull shark, 6'",
#  "4' to 6' shark",
#  'Tiger shark, 2m',
#  'White shark',
#  "6' shark, possibly a blactip or spinner shark",
#  "6' shark",
#  "White shark, >6'",
#  "Possibly a 5' to 6' sandtiger shark",
#  '4 m shark',
#  'Grey reef shark ',
#  "Bull shark, 6'",
#  'White shark, 3m to 4m',
#  'Bull shark, 3m female',
#  "Bull shark, 6'",
#  "White shark, 5' k",
#  "5' shark",
#  "Oceanic whitetip shark, 7'",
#  "Blacktip shark, 4'",
#  "Sevengill shark, 6' to 8'",
#  "3' to 4' shark",
#  'Blacktip reef shark ',
#  'White shark',
#  "Tiger shark, 10'",
#  'Tiger shark',
#  'Zambesi shark',
#  ' Tiger shark, 2.8m',
#  "Sandbar shark, 8'",
#  'Invalid',
#  "Bull shark, 12'",
#  'reef shark, 1.5m',
#  "1' to 2' shark",
#  'possibly a bronze whaler shark',
#  ' Bull shark, 2.5 m',
#  'Blacktip shark pup',
#  'Bull shark',
#  'Bull shark, 2.5m',
#  '3 m to 4 m shark',
#  'Bull shark, 2m',
#  '1.5 m shark',
#  'White shark x 2',
#  '1 m shark',
#  "6' shark",
#  'Caribbean reef shark',
#  'White shark',
#  "6' shark",
#  'Oceanic whitetip shark, 2.5m ',
#  'Mako shark ',
#  'Mako shark',
#  'Oceanic whitetip shark, 2.5m, female',
#  'Oceanic whitetip shark, 2.5m, female',
#  'White shark',
#  'White shark',
#  "Porbeagle shark, 8' ",
#  "White shark, 14' to 18' ",
#  'Bull shark, 1.4m ',
#  'Lemon shark',
#  "Possibly a 6' lemon shark",
#  'White shark',
#  'White shark',
#  '2m shark',
#  "3' shark",
#  'White shark',
#  'White shark',
#  '3 m shark',
#  "White shark, 15'",
#  "3' to 4' shark",
#  "4' shark",
#  'Possibly a small blacktip shark',
#  "Sandtiger shark, 4' to 5'",
#  'A small spinner shark',
#  'Angel shark',
#  'Nurse shark, juvenile ',
#  "Blue shark, 7'",
#  "4' shark",
#  "8' shark",
#  "Bull shark, 5'",
#  '1 m shark',
#  "4' shark",
#  "Lemon shark, 4'",
#  '20 to 30kg shark',
#  '20 to 30kg shark',
#  "4' shark",
#  "Lemon shark, 6'",
#  "14' shark",
#  '2 m shark',
#  "Oceanic whitetip shark, 6'",
#  '1.5 m shark',
#  'Possibly a blue shark',
#  '3 m shark',
#  '2 m shark',
#  'Wobbegong shark, 1.6m',
#  '2 m to 3 m shark',
#  'White shark, 2.5m',
#  "Spinner shark, 6'",
#  'Invalid',
#  '1.5 m shark',
#  'Thought to involve a juvenile hammerhead shark',
#  'White shark',
#  'Whitetip reef shark, 1m',
#  'Zambesi shark, 2m ',
#  'Bull shark, 3m',
#  'White shark, 2.8 to 3 m ',
#  'White shark',
#  "Sandtiger shark, 8'",
#  "6' shark",
#  'Thresher shark',
#  "4' shark",
#  '2 m shark',
#  'White shark, 4m',
#  'Zambesi shark',
#  "6' to 8' shark",
#  'Angel shark',
#  "Bull shark, 10'",
#  'Spurdog',
#  "Bull shark, 8'",
#  'Invalid',
#  "4' shark",
#  'White shark',
#  "White shark, 5' to 6' juvenile ",
#  'White shark, 2m',
#  'Tiger shark, 12',
#  'Bull shark?',
#  'Bull shark',
#  "Caribbean reef shark, 6'",
#  "5' shark",
#  "Nurse shark, 6'",
#  'Thought to involve a Bronze whale shark, 2m',
#  'Shark involvement probable, but not confirmed',
#  'White shark',
#  'Oceanic whitetip shark',
#  'Oceanic whitetip shark',
#  'Oceanic whitetip shark, 2.5 to 3m',
#  '80 kg shark',
#  "5' to 8' shark",
#  'blacktip or spinner shark',
#  'blacktip or spinner shark',
#  'blacktip or spinner shark',
#  "Blacktip shark, 4'",
#  "7' shark",
#  "2' to 3' shark",
#  "2' to 3' shark",
#  "White shark, 12' to 15' female",
#  'Raggedtooth shark',
#  'Bronze whaler shark?',
#  "3' to 4' shark",
#  'Blacktip reef shark pup',
#  'Thought to involve a cookie cutter shark',
#  'Wobbegong shark, 60cm',
#  'Blue shark, 1m',
#  '2.6 m shark',
#  'White shark, 2.5m ',
#  'Bull shark, 2.7 m ',
#  "White shark, 12' ",
#  'Bull shark',
#  'Tiger shark',
#  'Invalid',
#  'White shark, 5.5 m ',
#  'White sharks',
#  'Dusky shark, 2m',
#  'White shark, 5m',
#  'White shark, 3.5m',
#  'Mako shark, 3m',
#  'Broadnose sevengill shark',
#  'Bull shark',
#  '2 m shark',
#  'White shark, 4m to 5m ',
#  '4 to 5m white shark',
#  'White shark',
#  'Bronze whaler shark?',
#  'Raggedtooth shark, 2m',
#  'White shark, 4.5 to 5 m ',
#  'Zambesi shark?',
#  'Oceanic whitetip shark',
#  'Bronze whaler shark',
#  'Grey nurse shark, 3m',
#  'Lemon shark',
#  ' reef shark, 1.8m',
#  '5 m white shark',
#  "+3' shark",
#  'Bronze whaler shark',
#  "2' to 3' juvenile shark",
#  'Tiger shark',
#  "White shark, 14' to 16' ",
#  '3 m shark',
#  "4' shark",
#  'Blue shark',
#  "6' shark",
#  "8' bull shark or Caribbean reef shark",
#  "Tiger shark, 12'",
#  "8' white shark or 7-gill shark",
#  'White shark',
#  "3'  shark",
#  "2'  shark",
#  "2' to 3' reef shark",
#  "3' shark",
#  "3' to 4' shark",
#  "4' shark",
#  'Oceanic whitetip shark',
#  'Starry smoothhound shark, 1m',
#  "Bull shark, 6' to 7'",
#  'White shark, 2m',
#  'White shark, 4.5m',
#  "4.5 to 5' shark",
#  "White shark, 15'",
#  'Basking shark',
#  "5' shark",
#  'Bull shark',
#  'Tiger sharks in area',
#  '3 m shark',
#  '2 m shark',
#  'White shark, 4m',
#  '2 small bull sharks',
#  'Tiger shark',
#  "4' shark",
#  'Bull shark, 1.8m',
#  "White shark, 12' to 15'",
#  'Tiger shark, 2.3m ',
#  "Tiger shark, 13' female",
#  'Reported by media as shark attack, but shark involvement prior to death was not confirmed',
#  "1.5' to 2' shark",
#  "6' shark",
#  'Bull shark',
#  "4' to 5' shark",
#  'a small shark',
#  "2.5' shark",
#  'White shark',
#  'A bull shark, according to some of the divers on the boat',
#  '1 m shark',
#  "3' shark",
#  "Goblin shark, 4.2'",
#  'Blacktip shark, 2m',
#  'Mako shark, 90kg',
#  'Bronze whaler shark, 4m',
#  'a small shark',
#  "Nurse shark, 10'",
#  'Possibly a hammerhead shark',
#  '3 m shark',
#  'Invalid',
#  '2 m shark',
#  '"a small shark"',
#  'Not a shark attack; it was a hoax',
#  'Tiger shark',
#  '2.27 m shark',
#  'reef shark',
#  '1.5 to 2 m shark',
#  "4' to 5' shark",
#  "5' shark",
#  'White shark, 3m to 4m',
#  'Invalid',
#  'Tiger shark',
#  'White shark, 2.5m ',
#  'Bronze whaler shark',
#  "3' to 4' shark",
#  "Blacktip shark, 5'",
#  'Tiger shark',
#  'Caribbean reef shark',
#  'White shark',
#  'Oceanic whitetip sharks were in the vicinity',
#  "4' shark",
#  "3' shark",
#  'Gray reef shark',
#  "9.5' shark?",
#  "Nurse shark, 2' to 3' ",
#  '18" to 24" shark',
#  'Possibly a spinner shark',
#  "Tiger shark, 10' to 12' ",
#  "White shark, 12'",
#  "3' shark",
#  "3' shark",
#  'Sand shark',
#  'Sandtiger shark',
#  "4' to 5' shark",
#  "Possibly a 6' bull shark",
#  ' ',
#  "Possibly a 10' bull shark",
#  "White shark, 12' ",
#  'White shark',
#  ' ',
#  'Bronze whaler shark, 1.5 m ',
#  "2' to 3' shark",
#  "3' small spotted catshark, Scyliorhinus canicula",
#  "5' shark",
#  "Bull shark, 5' ",
#  '2 m shark',
#  'Questionable Incident',
#  "Lemon shark, 6' female ",
#  "4' shark",
#  'Tiger shark',
#  "3' to 4' shark",
#  'A 10-year-old 94-pound pregnant blacktip reef shark',
#  'Lesser spotted dogfish, Scyliorhinus canicula, less than 80 cm in length',
#  '2.5 m shark',
#  "10' shark",
#  "4' to 5' shark",
#  'White shark, 2m ',
#  "Tiger shark, 14' ",
#  "6' to 8' shark",
#  'Lemon shark, >1 m ',
#  '"a small shark"',
#  'blacktip or spinner shark',
#  "3' to 4' shark",
#  "Bull shark, 10' ",
#  'Tiger shark',
#  "3' shark",
#  "4' to 5' shark",
#  '1.5 m shark',
#  "5' shark",
#  '2 to 2.5 m shark',
#  'Tiger shark',
#  'Tiger shark',
#  "14' shark",
#  'White shark, 3m',
#  'Tiger shark',
#  '2.4 m shark',
#  '24" to 30" shark',
#  "6' to 8' shark, possibly a tiger shark",
#  '2.5 to 3 m shark',
#  '2 to 3 m shark',
#  "White shark, 12' to 15' ",
#  'Raggedtooth shark, 150-kg',
#  'White shark, 5m ',
#  '2 m to 3 m shark',
#  'Bull shark, 1.5m ',
#  "White shark, 16' ",
#  "1' to 4' shark",
#  "3' to 3.5' shark",
#  'Invalid',
#  'Nurse shark',
#  'Spinner shark',
#  "5' shark",
#  "3' shark",
#  'White shark, 3.5m ',
#  "Bronze whaler shark, 6'",
#  '5 m shark',
#  'White shark',
#  'Bull shark, 1.5m ',
#  'small catsharks',
#  'White shark?',
#  'Thought to involve a mako shark, but possibly a sea lion',
#  'White shark, 3m to 4m',
#  ' ',
#  "Bull shark, 4' to 5' ",
#  'Angel shark, 1.2m ',
#  'Bull or tiger shark',
#  "5' to 6' spinner or bull shark",
#  '1.8 m blacktip "reef" shark',
#  '1.8 m blacktip "reef" shark',
#  "Possibly a 1' to 3' blacktip or spinner shark",
#  "2' to 3' shark",
#  "3' to 4' shark",
#  "14' white shark",
#  "Tiger shark, 8' to 12'",
#  "Tiger shark, 15' female",
#  "Grey reef shark, 5' to 8' ",
#  "Tiger shark, 10' to 12'",
#  'Wobbegong shark, 2 m ',
#  'Invalid',
#  "Bull shark, 4' to bull shark",
#  'Bronze whaler shark, a  juvenile ',
#  'Raggedtooth shark, 2.5 m to 3 m ',
#  'Tiger shark',
#  '3 m, 600-kg shark',
#  "Tiger shark, 10'  ",
#  "Tiger shark, 5' ",
#  'Bronze whaler shark, 2 m',
#  "5' to 7' shark",
#  'Invalid',
#  '4.5 m white shark',
#  'Raggedtooth shark',
#  'Tiger shark',
#  "12' to 18' shark",
#  "12' shark",
#  '3.5 m white shark',
#  'Invalid',
#  'Bull shark',
#  "4' shark",
#  'Said to involve a 1.5 m shark',
#  'White shark',
#  'Tiger shark',
#  '3 m shark',
#  'Whitetip reef shark',
#  '4 m white shark',
#  "4' shark",
#  '3 m white shark',
#  '1.8 m shark',
#  "4' shark",
#  '4.5 m white shark',
#  'Raggedtooth shark, 2.5m ',
#  "6' shark",
#  "12' to 14' white shark",
#  "2' to 3' shark",
#  "2' shark",
#  '3 m shark',
#  'White shark',
#  "18' white shark",
#  "Tiger shark, less than 10'",
#  'Caribbean reef sharks',
#  'White shark',
#  'Tiger shark, 3 m ',
#  "14' to 16' white shark",
#  'Bronze whaler shark',
#  "3' to 4' shark",
#  'Bull shark',
#  "4 m [13'] white shark",
#  "2 m [6.75'] shark, 200-kg shark T",
#  'White shark',
#  'juvenile white shark',
#  'Possibly a sandbar shark or small blacktip shark',
#  "1.8 m [6'] shark",
#  'Invalid',
#  "3.5 m [11.5']shark",
#  "[4.5' to 5'] shark",
#  "[4' to 5']",
#  'Bull shark',
#  "1.8 m [6'] bull shark",
#  'On 8/13/2005 anglers from New Zealand caught a 2.8 m [9\'3"], 140-kg [309-lb] shark at the same spot. It was believed this was the same shark that killed Alysha',
#  'Invalid',
#  'Unknown, but it was reported that a shark tooth was recovered from the wound',
#  "3 m [10'] white shark",
#  "Mr. Burgess of ISAF announced the injury was the bite of a 1.8 m [6'], 2- to 3-year old white shark. Subsequent investigation revealed there was  no shark involvement in this incident",
#  'White shark',
#  '"small shark"',
#  '18" to 36" shark',
#  'Raggedtooth shark',
#  'Blacktip shark',
#  "Tiger shark, 8' to 9' ",
#  '2.5 m shark',
#  "Tiger shark, 3 m [10']",
#  "Mako shark, 1.5 m [5'] ",
#  "2 m [6.75'] copper shark",
#  'Bronze whaler shark',
#  "1.8 m [6'] blacktip shark",
#  'small hammerhead shark',
#  "4 m [13'] shark",
#  "6 m [20'] white shark",
#  "Sandtiger shark, 2.1 m [7'] ",
#  'Invalid',
#  "Bronze whaler shark, 4.3 m [14'] ",
#  'Bull shark',
#  "Nurse shark, 3' ",
#  "Tiger shark, 2.4 m [8']",
#  "1.8 m [6'] Caribbean reef shark",
#  "3 m [10'] shark",
#  '3 m shark',
#  "Bronze whaler shark, 2 m to 3 m [6.75' to 10']  ",
#  'White shark',
#  '4.5 m & 5 m white shark ',
#  'Bull shark',
#  'Raggedtooth shark',
#  'Raggedtooth shark',
#  "6 m [20'] white shark",
#  "5.5 m [18'] white shark",
#  '3 m shark',
#  "2.5 m [8.25'] bull shark",
#  'Invalid',
#  "2 m [6.75'] white shark",
#  "Bronze whaler shark, 2.4 m [8'] ",
#  "1.8 m to 2.4 m [6' to 8'] white shark",
#  "Tiger shark, 2.4 m to 3.7 m [8' to 12'] ",
#  "Raggedtooth shark, 1.5 to 2 m [5' to 6.75']",
#  'Thought to involve a 2.5 m bull or tiger shark',
#  "Tiger shark, 3 m [10'] ",
#  'White shark',
#  "2.4 m [8'] shark",
#  'Tiger shark, 1.5 m ',
#  "0.9 m to 1.2 m [3' to 4'] white shark",
#  "4.9 m to 5.5 m [16' to 18'] white shark",
#  "1.2 m [4'] shark",
#  "3 m to 4 m [10' to 13']  white shark",
#  'White shark',
#  "1.8 m [6'] shark",
#  "1.2 m to 1.5 m [4' to 5'] shark",
#  'Bull shark',
#  "4 m [13'] white shark",
#  "Longfin mako shark, 3.5 m [11.5'], 350-kg [772-lb] ",
#  '2 sharks, 4.5 m & 3 m ',
#  '"black tipped" shark',
#  "4' to 5' shark",
#  '9\'2" white shark',
#  'Invalid',
#  "Bronze whaler shark, 2.5 m [8.25'] ",
#  "1.2 m [4'] shark",
#  'White shark',
#  "0.9 m to 1.5 m [3' to 5'] shark",
#  'Bull shark',
#  "2.4 m to 3.7 m [8' to 12'] shark",
#  "1,5 m [5'] Caribbean reef shark (Carcharhinus  perezi)",
#  "Mako shark, 1.8 m [6']",
#  "Wobbegong shark, 1.2 m [4'] k",
#  "White shark, 5.5 m [18']",
#  ...]

# %%
df_sharks.shape
# Out:
# (3145, 17)

# %%
#there were some injuries not related to shark attacks, they were dropped with the function above.

df_sharks["Injury"].value_counts()
check_i = df_sharks["Injury"].value_counts()
print(check_i.to_string())
# Out:
# FATAL                                                                                                                                                                                                     196
# No injury                                                                                                                                                                                                  65
# Foot bitten                                                                                                                                                                                                41
# Leg bitten                                                                                                                                                                                                 39
# Survived                                                                                                                                                                                                   28
# No injury, board bitten                                                                                                                                                                                    25
# Left foot bitten                                                                                                                                                                                           25
# Right foot bitten                                                                                                                                                                                          16
# Thigh bitten                                                                                                                                                                                               16
# Calf bitten                                                                                                                                                                                                12
# FATAL, body not recovered                                                                                                                                                                                  11
# No injury to occupants                                                                                                                                                                                     11
# Foot lacerated                                                                                                                                                                                             11
# No details                                                                                                                                                                                                 11
# No injury, kayak bitten                                                                                                                                                                                    11
# Right leg bitten                                                                                                                                                                                           10
# Lacerations to left foot                                                                                                                                                                                   10
# No injury, surfboard bitten                                                                                                                                                                                10
# Hand bitten                                                                                                                                                                                                10
# Left arm bitten                                                                                                                                                                                             9
# Ankle bitten                                                                                                                                                                                                9
# Lacerations to foot                                                                                                                                                                                         8
# Right thigh bitten                                                                                                                                                                                          8
# Arm bitten                                                                                                                                                                                                  8
# Thigh lacerated                                                                                                                                                                                             8
# Left calf bitten                                                                                                                                                                                            8
# Lacerations to right foot                                                                                                                                                                                   7
# Minor injuries                                                                                                                                                                                              7
# No injury, ski bitten                                                                                                                                                                                       7
# Right calf bitten                                                                                                                                                                                           7
# Lacerations to right leg                                                                                                                                                                                    7
# Minor injury                                                                                                                                                                                                7
# Left hand bitten                                                                                                                                                                                            7
# Right foot lacerated                                                                                                                                                                                        6
# Forearm bitten                                                                                                                                                                                              6
# Lacerations to left calf                                                                                                                                                                                    6
# Left leg bitten                                                                                                                                                                                             6
# Knee bitten                                                                                                                                                                                                 5
# Puncture wounds to foot                                                                                                                                                                                     5
# Left arm lacerated                                                                                                                                                                                          5
# FATAL, legs bitten                                                                                                                                                                                          5
# Lacerations to left hand                                                                                                                                                                                    5
# Lacerations to right hand                                                                                                                                                                                   5
# Lacerations to hand                                                                                                                                                                                         5
# Lacerations to left forearm                                                                                                                                                                                 5
# Right calf lacerated                                                                                                                                                                                        5
# No injury, board damaged                                                                                                                                                                                    5
# Leg lacerated                                                                                                                                                                                               5
# Left thigh lacerated                                                                                                                                                                                        5
# Legs bitten                                                                                                                                                                                                 5
# Laceration to left foot                                                                                                                                                                                     5
# Swim fin bitten                                                                                                                                                                                             4
# Right foot & ankle lacerated                                                                                                                                                                                4
# No injury, shark bit surfboard                                                                                                                                                                              4
# Left forearm bitten                                                                                                                                                                                         4
# Laceration to right foot                                                                                                                                                                                    4
# Leg severely bitten, surgically amputated                                                                                                                                                                   4
# Elbow bitten                                                                                                                                                                                                4
# FATAL, leg severed                                                                                                                                                                                          4
# Heel bitten                                                                                                                                                                                                 4
# Lower leg bitten                                                                                                                                                                                            4
# No Injury, board bitten                                                                                                                                                                                     4
# Left calf lacerated                                                                                                                                                                                         4
# No injury, swim fin bitten                                                                                                                                                                                  4
# Foot severed                                                                                                                                                                                                4
# Arm lacerated                                                                                                                                                                                               4
# No injury to occupants, shark bit boat                                                                                                                                                                      4
# Lacerations to fingers                                                                                                                                                                                      4
# Laceration to left hand                                                                                                                                                                                     4
# Finger bitten by hooked shark PROVOKED INCIDENT                                                                                                                                                             4
# Right hand lacerated                                                                                                                                                                                        4
# Lacerations to leg                                                                                                                                                                                          3
# Puncture wounds to right foot                                                                                                                                                                               3
# Lacerations to lower leg                                                                                                                                                                                    3
# Right arm bitten                                                                                                                                                                                            3
# Arm bitten by captive shark PROVOKED INCIDENT                                                                                                                                                               3
# Leg bitten                                                                                                                                                                                                  3
# FATAL, thigh bitten                                                                                                                                                                                         3
# Torso lacerated                                                                                                                                                                                             3
# Minor injuries to hand                                                                                                                                                                                      3
# Probable drowning & scavenging                                                                                                                                                                              3
# Foot bitten by landed shark PROVOKED INCIDENT                                                                                                                                                               3
# Hand lacerated                                                                                                                                                                                              3
# Arm severed                                                                                                                                                                                                 3
# Leg bitten, surgically amputated                                                                                                                                                                            3
# Left ankle bitten                                                                                                                                                                                           3
# No injury, shark bit board                                                                                                                                                                                  3
# No injury, shark bit kayak                                                                                                                                                                                  3
# Shark bites were post-mortem                                                                                                                                                                                3
# Lower leg lacerated                                                                                                                                                                                         3
# Abrasion                                                                                                                                                                                                    3
# No injury to occupant                                                                                                                                                                                       3
# Ankle lacerated                                                                                                                                                                                             3
# Lower right leg lacerated                                                                                                                                                                                   3
# Laceration to leg                                                                                                                                                                                           3
# Lower left leg bitten, surgically amputated                                                                                                                                                                 3
# No injury, board bumped by shark                                                                                                                                                                            3
# Shoulder bitten                                                                                                                                                                                             3
# Thigh & calf bitten                                                                                                                                                                                         3
# Torso bitten                                                                                                                                                                                                3
# Lacerations to right forearm                                                                                                                                                                                3
# Lower legs bitten                                                                                                                                                                                           3
# Lacerations to right calf                                                                                                                                                                                   3
# Left ankle & foot bitten                                                                                                                                                                                    3
# Right hand bitten by hooked shark PROVOKED INCIDENT                                                                                                                                                         3
# Lacerations to right arm                                                                                                                                                                                    3
# Lacerations to lower left leg                                                                                                                                                                               3
# Leg severed at knee                                                                                                                                                                                         3
# Buttocks bitten                                                                                                                                                                                             3
# No injury, rammed by shark                                                                                                                                                                                  3
# Calf lacerated                                                                                                                                                                                              3
# Abrasions                                                                                                                                                                                                   3
# Ankle & foot lacerated                                                                                                                                                                                      3
# Laceration to thigh                                                                                                                                                                                         3
# Buttock & leg bitten                                                                                                                                                                                        2
# Right ankle & foot bitten                                                                                                                                                                                   2
# No injury, surfboard leash severed                                                                                                                                                                          2
# Lacerations to legs                                                                                                                                                                                         2
# FATAL, leg bitten                                                                                                                                                                                           2
# FATAL, body was not recovered                                                                                                                                                                               2
# Laceration to right lower leg                                                                                                                                                                               2
# FATAL                                                                                                                                                                                                       2
# Minor injury to torso                                                                                                                                                                                       2
# Laceration to calf                                                                                                                                                                                          2
# Leg bitten by hooked shark PROVOKED INCIDENT                                                                                                                                                                2
# No injury, kayak damaged                                                                                                                                                                                    2
# FATAL?                                                                                                                                                                                                      2
# FATAL, thigh bitten                                                                                                                                                                                         2
# Hooked shark bit boat PROVOKED INCIDENT                                                                                                                                                                     2
# Upper left arm bitten                                                                                                                                                                                       2
# Laceration to foot                                                                                                                                                                                          2
# Punctures on left thigh                                                                                                                                                                                     2
# Drowned, body scavenged by shark                                                                                                                                                                            2
# Shin lacerated                                                                                                                                                                                              2
# Shin bitten                                                                                                                                                                                                 2
# Shark bumped boat, no injury to occupants                                                                                                                                                                   2
# Lacerations to calf                                                                                                                                                                                         2
# Left foot lacerated                                                                                                                                                                                         2
# 2-inch laceration to upper left arm                                                                                                                                                                         2
# Leg & foot bitten                                                                                                                                                                                           2
# FATAL, but shark involvement prior to death was not confirmed                                                                                                                                               2
# Lacerations to calf by hooked shark PROVOKED INCIDENT                                                                                                                                                       2
# Leg severed                                                                                                                                                                                                 2
# Left elbow bitten                                                                                                                                                                                           2
# Minor laceration to hand                                                                                                                                                                                    2
# Top of left foot bitten                                                                                                                                                                                     2
# FATAL                                                                                                                                                                                                       2
# Right hand severed                                                                                                                                                                                          2
# No injury to occupant, shark/s holded  kayak                                                                                                                                                                2
# Minor lacerations to foot                                                                                                                                                                                   2
# Left foot & leg bitten                                                                                                                                                                                      2
# Leg & surfboard bitten                                                                                                                                                                                      2
# Right knee lacerated                                                                                                                                                                                        2
# Lacerations to right arm & thigh                                                                                                                                                                            2
# Hands severed                                                                                                                                                                                               2
# Big toe bitten                                                                                                                                                                                              2
# Recorded as PROVOKED INCIDENT                                                                                                                                                                               2
# Lacerations to arm & leg                                                                                                                                                                                    2
# Right leg severely bitten                                                                                                                                                                                   2
# Left shoulder bitten                                                                                                                                                                                        2
# Calf nipped in each case                                                                                                                                                                                    2
# Left calf injured                                                                                                                                                                                           2
# No injury to occupants, boat damaged                                                                                                                                                                        2
# Thigh gashed                                                                                                                                                                                                2
# Upper right thigh bitten                                                                                                                                                                                    2
# Left forearm bitten PROVOKED INCIDENT                                                                                                                                                                       2
# Minor injury to foot                                                                                                                                                                                        2
# Left leg lacerated                                                                                                                                                                                          2
# Presumed FATAL, body not recovered                                                                                                                                                                          2
# No injury to occupant, shark rammed boat                                                                                                                                                                    2
# Lacerations                                                                                                                                                                                                 2
# Left foot lacerated                                                                                                                                                                                         2
# No injury, shark bit paddleboard                                                                                                                                                                            2
# Lacerations to thigh & buttocks                                                                                                                                                                             2
# Injuries to right foot                                                                                                                                                                                      2
# Lacerations to forearm                                                                                                                                                                                      2
# Hand bitten by hooked shark PROVOKED INCIDENT                                                                                                                                                               2
# No injury, shark bit surfboard                                                                                                                                                                              2
# FATAL, right thigh bitten                                                                                                                                                                                   2
# No injury, knocked off board                                                                                                                                                                                2
# Lacerations to thigh                                                                                                                                                                                        2
# FATAL, legs severed                                                                                                                                                                                         2
# Minor injury to arm                                                                                                                                                                                         2
# Thigh bitten, FATAL                                                                                                                                                                                         2
# Puncture wounds to right calf                                                                                                                                                                               2
# Severe lacerations to left foot                                                                                                                                                                             2
# Right leg lacerated                                                                                                                                                                                         2
# Foot & ankle lacerated                                                                                                                                                                                      2
# No injury                                                                                                                                                                                                   2
# Puncture wounds on right foot                                                                                                                                                                               2
# Disappeared, but shark involvement unconfirmed                                                                                                                                                              2
# Lower left leg bitten                                                                                                                                                                                       2
# FATAL PROVOKED INCIDENT                                                                                                                                                                                     2
# Hand injured                                                                                                                                                                                                2
# No injury to occupants, shark bit propeller                                                                                                                                                                 2
# No Injury                                                                                                                                                                                                   2
# No Injury to occupants                                                                                                                                                                                      2
# Knee lacerated                                                                                                                                                                                              2
# Right leg severed, left leg lacerated                                                                                                                                                                       2
# Leg injured                                                                                                                                                                                                 2
# No injury, shark made a threat display                                                                                                                                                                      2
# FATAL, leg bitten                                                                                                                                                                                           2
# Lacerations to right lower leg                                                                                                                                                                              2
# Minor lacerations to right foot                                                                                                                                                                             2
# Foot & ankle bitten                                                                                                                                                                                         2
# Laceration to left thigh                                                                                                                                                                                    2
# No injury. Hull bitten, tooth fragment recovered                                                                                                                                                            2
# Lacerations to arm                                                                                                                                                                                          2
# No injury, no attack                                                                                                                                                                                        2
# Lacerations and puncture wounds in right arm                                                                                                                                                                1
# Lower leg nipped, arm bruised when he landed in boat                                                                                                                                                        1
# Right arm & right leg bitten                                                                                                                                                                                1
# Puncture wounds to right thigh                                                                                                                                                                              1
# No injury to occupants. Shark  gouged planks of boat                                                                                                                                                        1
# Thigh & swim fin bitten                                                                                                                                                                                     1
# Right hand & foot severed, thigh & buttock lacerated                                                                                                                                                        1
# Lower leg bitten & foot severed, leg surgically amputated below knee                                                                                                                                        1
# No injury, shark's tail struck his armpit                                                                                                                                                                   1
# One woman reported to have suffered fish bites, but cause of her death was exposure & drowning"                                                                                                             1
# Foot lacerated  PROVOKED INCIDENT                                                                                                                                                                           1
# 7 puncture wounds in right forearm from hooked shark PROVOKED INCIDENT                                                                                                                                      1
# FATAL, arm severed, leg bitten                                                                                                                                                                              1
# Torso & hand lacerated                                                                                                                                                                                      1
# Leg & thigh bitten                                                                                                                                                                                          1
# No injury, shark charged & impaled itself on spear                                                                                                                                                          1
# No injury to occupants, shark holed  boat                                                                                                                                                                   1
# Left leg severed                                                                                                                                                                                            1
# No injury to occupant, shark bit propeller of outboard motor                                                                                                                                                1
# Thigh & hand bitten                                                                                                                                                                                         1
# No injury to occupants, drove sharks away with paddles                                                                                                                                                      1
# Abrasions & 11 teethmarks on right lower leg                                                                                                                                                                1
# Minor injury, abdomen abraded when he collided with the shark                                                                                                                                               1
# FATAL, torso / abdomen severely bitten                                                                                                                                                                      1
# ...
# Lacerations to right hand & wrist                                                                                                                                                                           1
# Lacerations to buttocks                                                                                                                                                                                     1
# Lower legs lacerated                                                                                                                                                                                        1
# Buttock bitten, hands lacerated                                                                                                                                                                             1
# A cut on her hand                                                                                                                                                                                           1
# Six puncture wounds on  leg                                                                                                                                                                                 1
# No injury to occupant; shark bit propeller                                                                                                                                                                  1
# Fingers bitten PROVOKED INCIDENT                                                                                                                                                                            1
# No injury to diver, speargun damaged                                                                                                                                                                        1
# Reported as shark attack but probable drowning                                                                                                                                                              1
# Sharks prevented recovery of remains                                                                                                                                                                        1
# Right forearm severed surgically amputated above elbow                                                                                                                                                      1
# Puncture wounds on right hip and arm                                                                                                                                                                        1
# No injury to occupants, boat's rear platform bitten                                                                                                                                                         1
# No injury. Shark made threat display, then diver shot the shark PROVOKED INCIDENT                                                                                                                           1
# Arm severed, surgically reattached                                                                                                                                                                          1
# No Injury to occupants; shark bumped the boat                                                                                                                                                               1
# Calf, foot & hand bitten                                                                                                                                                                                    1
# Hand bitten by captive shark PROVOKED INCIDENT                                                                                                                                                              1
# Lacerations on heel & dorsum of right foot                                                                                                                                                                  1
# 2 small puncture wounds on left foot PROVOKED INCIDENT                                                                                                                                                      1
# Bitten above & below right knee                                                                                                                                                                             1
# Left thigh bitten, leg surgically amputated                                                                                                                                                                 1
#  Ankle lacerated                                                                                                                                                                                            1
# Thigh lacerated  PROVOKED INCIDENT                                                                                                                                                                          1
# Left thumb lacerated PROVOKED INCIDENT                                                                                                                                                                      1
# No injury, surfboard bitten                                                                                                                                                                                 1
# Right hand severely lacerated                                                                                                                                                                               1
# Left hand lacerated and abraded                                                                                                                                                                             1
# Heel & back of right knee lacerated                                                                                                                                                                         1
# Abrasions on right hand & deep laceration on middle finger                                                                                                                                                  1
# Left foot bitten                                                                                                                                                                                            1
# 1.5-inch laceration                                                                                                                                                                                         1
# Right upper am, shoulder & back severely  bitten                                                                                                                                                            1
# Right shoulder forarm & wrist bitten                                                                                                                                                                        1
# Both legs severely lacerated                                                                                                                                                                                1
# Minor injury to right calf                                                                                                                                                                                  1
# Groin bitten                                                                                                                                                                                                1
# Forearms lacerated                                                                                                                                                                                          1
# No injury, but her surfboard was bitten                                                                                                                                                                     1
# Puncture wounds on heel, legs and buttocks                                                                                                                                                                  1
# Arm lacerated (shark made 3 strikes)                                                                                                                                                                        1
# Hand nipped PROVOKED INCIDENT                                                                                                                                                                               1
# Left hand and wrist bitten                                                                                                                                                                                  1
# Right foot bitten, left leg severed                                                                                                                                                                         1
# Drowned when caught in line and pulled overboard by hooked shark PROVOKED INCIDENT                                                                                                                          1
# No injury, shark bit side of surfboard                                                                                                                                                                      1
# 2 bites behind knee                                                                                                                                                                                         1
# 6-inch gash on right foot                                                                                                                                                                                   1
# Back of left hand gashed                                                                                                                                                                                    1
# Cuts on right foot                                                                                                                                                                                          1
# Left buttock & foot  severed                                                                                                                                                                                1
# Head bitten by captive shark PROVOKED INCIDENT                                                                                                                                                              1
# 2 lacerations on lower back, punctures on buttock                                                                                                                                                           1
# FATAL or drowning & scavenging                                                                                                                                                                              1
# PROVOKED INCIDENT Several small lacerations on left foot                                                                                                                                                    1
# No injury from shark                                                                                                                                                                                        1
# Lacerations to right forearm & shoulder injured                                                                                                                                                             1
# No Injury, shark hit board                                                                                                                                                                                  1
# Lacerations to buttocks & thigh                                                                                                                                                                             1
# Foot & calf bitten                                                                                                                                                                                          1
# Leg bitten & surgically amputated                                                                                                                                                                           1
# Bruises & minor cuts                                                                                                                                                                                        1
# Stern of kayak bitten/chest bruised                                                                                                                                                                         1
# Heel / foot bitten                                                                                                                                                                                          1
# Several  puncture wounds on lower right leg                                                                                                                                                                 1
# Punctures on left foot and foot                                                                                                                                                                             1
# Left leg severed below knee                                                                                                                                                                                 1
# Two half-inch lacerations on right heel and one near small toe                                                                                                                                              1
# Drowned, his remains were found in a 3m [10'], 368 kg [811-lb] tiger shark                                                                                                                                  1
# FATAL, torso & leg bitten                                                                                                                                                                                   1
# Laceration to arm.                                                                                                                                                                                          1
# Toothmarks in board & his swim trunks                                                                                                                                                                       1
# Lacerated foot                                                                                                                                                                                              1
# Lacerated leg & back                                                                                                                                                                                        1
# Upper arm bitten                                                                                                                                                                                            1
# FATAL, knocked overboard by tail of shark & carried off by shark                                                                                                                                            1

# %%
df_sharks.head()
# Out:
#           Date  Year        Type    Country             Area  \
# 0  25-Jun-2018  2018        Boat        USA       California
# 3  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018  2018    Provoked     MEXICO           Colima
# 6  03-Jun-2018  2018  Unprovoked     BRAZIL       Pernambuco
# 7  27-May-2018  2018  Unprovoked        USA          Florida
#
#                                             Location     Activity  \
# 0                        Oceanside, San Diego County     Paddling
# 3                                 Arrawarra Headland      Surfing
# 4                                           La Ticla  Free diving
# 6                              Piedade Beach, Recife     Swimming
# 7  Lighhouse Point Park, Ponce Inlet, Volusia County      Fishing
#
#                      Name Sex  Age  \
# 0             Julie Wolfe   F   57
# 3                    male   M   27
# 4          Gustavo Ramos    M   27
# 6  Jose Ernesto da Silva    M   18
# 7                    male   M   52
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
# 6                                              FATAL           Y
# 7            Minor injury to foot. PROVOKED INCIDENT           N
#
#              Time          Species           Investigator or Source Month  \
# 0           18h00      White shark                 R. Collier, GSAF   jun
# 3             NaN        2 m shark                   B. Myatt, GSAF   jun
# 4             NaN  Tiger shark, 3m                        A .Kipper   jun
# 6  Late afternoon      Tiger shark   Diario de Pernambuco, 6/4/2018   jun
# 7             NaN  Lemon shark, 3'  K. McMurray, TrackingSharks.com   may
#
#   Provoked
# 0        N
# 3        N
# 4        Y
# 6        N
# 7        N

# %%
df_sharks["Investigator or Source"].isna().sum()
# Out:
# 6

# %%
#filling NaN investigation shource with Unknown
df_sharks["Investigator or Source"].fillna("Unknown", inplace=True)
df_sharks["Investigator or Source"].isna().sum()
# Out:
# 0

# %%
df_sharks.to_csv("./data/final_data_shark.csv")
